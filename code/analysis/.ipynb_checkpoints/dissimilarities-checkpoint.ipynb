# %%
setwd("/home/pasoneto/Documents/github/doc_suomi/code")
source("utils.R")
source("data_cook.R")
cat(howto_data)
# Out:
# `summarise()` regrouping output by 'album_id' (override with `.groups` argument)
# How to use datasets
#
# call    base()             for real values
# call    z_scored()         for normalized
# call    min_maxed()        for normalized2
# call    upsampled_album()  for binded upsamplped albums
# call    list_upsampled()   for list of upsampled albums
# call    low()              for normalized low level
# call    low_upsampled()    for normalized and upsampled low level

# %% [markdown]
# # Dissimilarities 1
#
# Dissimilarities with nearest neighbors upsampling. Each album was upsampled to 16 tracks, and then dissimilarities were calculated.

# %%
# Reading upsampled albums
file_list <- list.files(path="/home/pasoneto/Documents/github/doc_suomi/data/dissimilarities/upsampled_nearest")
matrices = c()

# Reading files
for(i in 1:length(file_list)){
    file = paste("/home/pasoneto/Documents/github/doc_suomi/data/dissimilarities/upsampled_nearest/", file_list[i], sep = "")
    matrices[[i]] = fread(file, header = TRUE)
}

matrices[[3831]] <- NULL

for(i in 1:length(matrices)){
    colnames(matrices[[i]]) <- c("track_number", "album_id", "valence", "energy", "loudness", "tempo")
    matrices[[i]]$album_id <- as.character(matrices[[i]]$album_id)
    matrices[[i]]$track_number <- c(seq(1, 16, 1))
}

matrices = dissim_gen(matrices)

dt <- matrix_parser(matrices,  function(x){mean(x, na.rm = TRUE)})
std <- matrix_parser(matrices, function(x){sd(x, na.rm = TRUE)/sqrt(length(x))})

redblack = colorRampPalette(c("red", "black"))(100)
levelplot(dt, col.regions = redblack)
# Out:
# plot without title

# %% [markdown]
# # Dissimilarities 2
#
# Each album was upsampled to 100 tracks with nearest neighbors. Then dissimilarities were calculated.

# %%
# Reading upsampled albums
file_list <- list.files(path="/home/pasoneto/Documents/github/doc_suomi/data/dissimilarities/upsampled_100")
matrices = c()

# Reading files
for(i in 1:length(file_list)){
    file = paste("/home/pasoneto/Documents/github/doc_suomi/data/dissimilarities/upsampled_100/", file_list[i], sep = "")
    matrices[[i]] = fread(file, header = TRUE)
}

matrices[[3831]] <- NULL

for(i in 1:length(matrices)){
    colnames(matrices[[i]]) <- c("track_number", "album_id", "valence", "energy", "loudness", "tempo")
    matrices[[i]]$album_id <- as.character(matrices[[i]]$album_id)
    matrices[[i]]$track_number <- c(seq(1, 100, 1))
}

matrices = dissim_gen(matrices)

dt <- matrix_parser(matrices,  function(x){mean(x, na.rm = TRUE)})
std <- matrix_parser(matrices, function(x){sd(x, na.rm = TRUE)/sqrt(length(x))})

redblack = colorRampPalette(c("red", "black"))(100)
levelplot(dt, col.regions = redblack)
# Out:
# plot without title

# %% [markdown]
# # Dissimilarities by track
#
# Dissimilarities by track.

# %%
library("tidyverse")

#Import list of dissimilarities
oi = list_upsampled() #upsampled using bilinear interpolation

#Renaming columns and resetting track_number
for(i in 1:length(oi)){
    oi[[i]]$`0` <- seq(1, 16, 1)
    colnames(oi[[i]]) <- c("track_number", "album_id", "valence", "energy", "loudness", "tempo")
}

#Generating dissimilarities
oi = dissim_gen(oi)

#Getting dissimilarity from each album
#each column represents the dissimilarity of track n with every other track
dissims = c()
for(k in 1:16){
    track = c()
    for(i in 1:length(oi)){ track <- c(track, oi[[i]][k, ])}
    dissims[[k]] <- unname(track)
}

#Generating data frame for visuals
names = c(); value = c()
for(i in 1:length(dissims)){
    names = c(names, rep(paste("track", i, sep = ""), 71120))
    value = c(value, dissims[[i]])    
}

visual_dissim = tibble(dissims = value, track_ref = names)

# Plotting
dp = visual_dissim %>%
    na.omit() %>% 
    mutate(track_ref = fct_reorder(.f = track_ref, .x = dissims, .fun = median)) %>% 
    ggplot(aes(x = dissims, y = track_ref, group = track_ref)) +
           ggridges::stat_density_ridges(aes(fill = track_ref),
                                         rel_min_height = 0.03, 
                                         scale = 5, 
                                         quantile_lines = TRUE, 
                                         quantiles = 2)+
    theme(legend.position = "none") + xlim(c(0, 1.6))

bp = visual_dissim %>%
    na.omit() %>% 
    mutate(track_ref = fct_reorder(.f = track_ref, .x = dissims, .fun = median)) %>% 
    ggplot(aes(y = dissims, x = track_ref, group = track_ref)) +
           geom_boxplot(aes(fill = track_ref)) +
    theme(axis.text.x = element_text(angle = 60))

pp = visual_dissim %>%
    na.omit() %>% 
    group_by(track_ref) %>%
    summarise(dissim = mean(dissims), stder = sd(dissims)/sqrt(length(dissims))) %>%
    mutate(track_ref = fct_reorder(.f = track_ref, .x = dissim, .fun = mean)) %>% 
    ggplot(aes(x = track_ref, y = dissim, fill = track_ref))+
        geom_point(size = 0.5)+
        geom_errorbar(aes(ymin = dissim-stder, ymax = dissim+stder)) +
    theme(axis.text.x = element_text(angle = 60))
# Out:
# ── Attaching packages ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ tibble  3.0.4     ✔ purrr   0.3.4
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.0
#
# ── Conflicts ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ data.table::between()   masks dplyr::between()
# ✖ randomForest::combine() masks dplyr::combine()
# ✖ tidyr::extract()        masks magrittr::extract()
# ✖ dplyr::filter()         masks stats::filter()
# ✖ data.table::first()     masks dplyr::first()
# ✖ dplyr::lag()            masks stats::lag()
# ✖ data.table::last()      masks dplyr::last()
# ✖ purrr::lift()           masks caret::lift()
# ✖ randomForest::margin()  masks ggplot2::margin()
# ✖ purrr::set_names()      masks magrittr::set_names()
# ✖ purrr::transpose()      masks data.table::transpose()
#
# `summarise()` ungrouping output (override with `.groups` argument)

# %% [markdown]
# # Dissimilarities 3
#
# Here I'm looking at overall dissimilarities for each track. Essentially what I'm asking is: "how dissimilar is track $n$ from all other tracks?"

# %% [markdown]
# ## Mean and standard error of dissimilarities by track

# %%
pp
# Out:
# plot without title

# %% [markdown]
# ## Boxplot of dissimilarities by track

# %%
bp
# Out:
# plot without title

# %% [markdown]
# ## Density plot of dissimilarities by track

# %%
dp
# Out:
# Picking joint bandwidth of 0.0287
#
# Warning message:
# “Removed 2812 rows containing non-finite values (stat_density_ridges).”
# plot without title

# %% [markdown]
# # Dissimilarities by album length
#
# Here I'm asking if the pattern of highest dissimilarities hold for albums regardless of their length. For instance, albums with 6 and albums with 16 tracks show the highest dissimilarities on their edges?

# %%
dt = base()
dt %<>% split(dt$album_length)
dt = dissim_by_length(dt)

# %%
for(i in 1:length(dt)){
    dt[[i]] <- matrix_parser(dt[[i]], function(x){mean(x, na.rm = TRUE)})
    print(levelplot(dt[[i]], col.regions = colorRampPalette(c("red", "black"))(100)))
}
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %% [markdown]
# # Getting descriptives for album length

# %%
dt = base()
dt %<>% split(dt$album_length)
dt = dissim_by_length(dt)
for(i in 1:length(dt)){
        dt[[i]] <- do.call(rbind, dt[[i]])
}

# %%
for(i in 1:length(dt)){
    dt[[i]] <- data.frame(dt[[i]])
    dt[[i]]$track_number <- rep(seq(1, i+5, 1), nrow(dt[[i]])/(i+5))  
    }

# %%
for(i in 1:length(dt)){
    
    ha = melt(dt[[i]], id.vars = c("track_number"), id.measures = c(colnames(dt[[i]])[1:length(dt[[i]])-1]))%>%
                na.omit() %>%
                group_by(track_number) %>%
                summarise(stderr = sd(value)/sqrt(length(value)), value = mean(value)) #%>%
               # mutate(track_number = fct_reorder(.f = as.factor(track_number), .x = value, .fun = mean))
    print(ggplot(ha, aes(x = as.factor(track_number), y = value)) +
                   geom_point()+
                   geom_errorbar(aes(ymin = value-stderr, ymax = value+stderr)))
    }
# Out:
# Warning message in melt(dt[[i]], id.vars = c("track_number"), id.measures = c(colnames(dt[[i]])[1:length(dt[[i]]) - :
# “The melt generic in data.table has been passed a data.frame and will attempt to redirect to the relevant reshape2 method; please note that reshape2 is deprecated, and this redirection is now deprecated as well. To continue using melt methods from reshape2 while both libraries are attached, e.g. melt.list, you can prepend the namespace like reshape2::melt(dt[[i]]). In the next version, this warning will become an error.”
# `summarise()` ungrouping output (override with `.groups` argument)
#
# Warning message in melt(dt[[i]], id.vars = c("track_number"), id.measures = c(colnames(dt[[i]])[1:length(dt[[i]]) - :
# “The melt generic in data.table has been passed a data.frame and will attempt to redirect to the relevant reshape2 method; please note that reshape2 is deprecated, and this redirection is now deprecated as well. To continue using melt methods from reshape2 while both libraries are attached, e.g. melt.list, you can prepend the namespace like reshape2::melt(dt[[i]]). In the next version, this warning will become an error.”
# `summarise()` ungrouping output (override with `.groups` argument)
#
# Warning message in melt(dt[[i]], id.vars = c("track_number"), id.measures = c(colnames(dt[[i]])[1:length(dt[[i]]) - :
# “The melt generic in data.table has been passed a data.frame and will attempt to redirect to the relevant reshape2 method; please note that reshape2 is deprecated, and this redirection is now deprecated as well. To continue using melt methods from reshape2 while both libraries are attached, e.g. melt.list, you can prepend the namespace like reshape2::melt(dt[[i]]). In the next version, this warning will become an error.”
# `summarise()` ungrouping output (override with `.groups` argument)
# plot without title
# Warning message in melt(dt[[i]], id.vars = c("track_number"), id.measures = c(colnames(dt[[i]])[1:length(dt[[i]]) - :
# “The melt generic in data.table has been passed a data.frame and will attempt to redirect to the relevant reshape2 method; please note that reshape2 is deprecated, and this redirection is now deprecated as well. To continue using melt methods from reshape2 while both libraries are attached, e.g. melt.list, you can prepend the namespace like reshape2::melt(dt[[i]]). In the next version, this warning will become an error.”
# `summarise()` ungrouping output (override with `.groups` argument)
# plot without title
# Warning message in melt(dt[[i]], id.vars = c("track_number"), id.measures = c(colnames(dt[[i]])[1:length(dt[[i]]) - :
# “The melt generic in data.table has been passed a data.frame and will attempt to redirect to the relevant reshape2 method; please note that reshape2 is deprecated, and this redirection is now deprecated as well. To continue using melt methods from reshape2 while both libraries are attached, e.g. melt.list, you can prepend the namespace like reshape2::melt(dt[[i]]). In the next version, this warning will become an error.”
# `summarise()` ungrouping output (override with `.groups` argument)
# plot without title
# Warning message in melt(dt[[i]], id.vars = c("track_number"), id.measures = c(colnames(dt[[i]])[1:length(dt[[i]]) - :
# “The melt generic in data.table has been passed a data.frame and will attempt to redirect to the relevant reshape2 method; please note that reshape2 is deprecated, and this redirection is now deprecated as well. To continue using melt methods from reshape2 while both libraries are attached, e.g. melt.list, you can prepend the namespace like reshape2::melt(dt[[i]]). In the next version, this warning will become an error.”
# `summarise()` ungrouping output (override with `.groups` argument)
# plot without title
# Warning message in melt(dt[[i]], id.vars = c("track_number"), id.measures = c(colnames(dt[[i]])[1:length(dt[[i]]) - :
# “The melt generic in data.table has been passed a data.frame and will attempt to redirect to the relevant reshape2 method; please note that reshape2 is deprecated, and this redirection is now deprecated as well. To continue using melt methods from reshape2 while both libraries are attached, e.g. melt.list, you can prepend the namespace like reshape2::melt(dt[[i]]). In the next version, this warning will become an error.”
# `summarise()` ungrouping output (override with `.groups` argument)
# plot without title
# Warning message in melt(dt[[i]], id.vars = c("track_number"), id.measures = c(colnames(dt[[i]])[1:length(dt[[i]]) - :
# “The melt generic in data.table has been passed a data.frame and will attempt to redirect to the relevant reshape2 method; please note that reshape2 is deprecated, and this redirection is now deprecated as well. To continue using melt methods from reshape2 while both libraries are attached, e.g. melt.list, you can prepend the namespace like reshape2::melt(dt[[i]]). In the next version, this warning will become an error.”
# `summarise()` ungrouping output (override with `.groups` argument)
# plot without title
# Warning message in melt(dt[[i]], id.vars = c("track_number"), id.measures = c(colnames(dt[[i]])[1:length(dt[[i]]) - :
# “The melt generic in data.table has been passed a data.frame and will attempt to redirect to the relevant reshape2 method; please note that reshape2 is deprecated, and this redirection is now deprecated as well. To continue using melt methods from reshape2 while both libraries are attached, e.g. melt.list, you can prepend the namespace like reshape2::melt(dt[[i]]). In the next version, this warning will become an error.”
# `summarise()` ungrouping output (override with `.groups` argument)
# plot without title
# Warning message in melt(dt[[i]], id.vars = c("track_number"), id.measures = c(colnames(dt[[i]])[1:length(dt[[i]]) - :
# “The melt generic in data.table has been passed a data.frame and will attempt to redirect to the relevant reshape2 method; please note that reshape2 is deprecated, and this redirection is now deprecated as well. To continue using melt methods from reshape2 while both libraries are attached, e.g. melt.list, you can prepend the namespace like reshape2::melt(dt[[i]]). In the next version, this warning will become an error.”
# `summarise()` ungrouping output (override with `.groups` argument)
# plot without title
# Warning message in melt(dt[[i]], id.vars = c("track_number"), id.measures = c(colnames(dt[[i]])[1:length(dt[[i]]) - :
# “The melt generic in data.table has been passed a data.frame and will attempt to redirect to the relevant reshape2 method; please note that reshape2 is deprecated, and this redirection is now deprecated as well. To continue using melt methods from reshape2 while both libraries are attached, e.g. melt.list, you can prepend the namespace like reshape2::melt(dt[[i]]). In the next version, this warning will become an error.”
# `summarise()` ungrouping output (override with `.groups` argument)
# plot without title
# plot without title
# plot without title

# %% [markdown]
# # Dissimilarity by low

# %%
low = low_upsampled()
low %<>%
    select('track_number', 'danceability', 'energy', 'loudness_overall', 'speechiness', 'acousticness', 'instrumentalness', 
    'liveness', 'valence', 'tempo_overall', 'loudness_continuouos', 'tempo_continuous', 'tempo_confidence', 'mode_confidence', 'time_signature_confidence', 
    'loudness', 'loudness_continuous', 'track_id', 'album_id') %>%

low = split(low, low$album_id)
# Out:
#         track_number danceability energy     loudness_overall speechiness
# 1       1            -0.4552073   0.2082680  -3.686            0.6048359
# 2       1            -0.4552073   0.2082680  -3.686            0.6048359
# 3       1            -0.4552073   0.2082680  -3.686            0.6048359
# 4       1            -0.4552073   0.2082680  -3.686            0.6048359
# 5       1            -0.4552073   0.2082680  -3.686            0.6048359
# 6       1            -0.4552073   0.2082680  -3.686            0.6048359
# 7       1            -0.4552073   0.2082680  -3.686            0.6048359
# 8       1            -0.4552073   0.2082680  -3.686            0.6048359
# 9       1            -0.4552073   0.2082680  -3.686            0.6048359
# 10      1            -0.4552073   0.2082680  -3.686            0.6048359
# 11      1            -0.4552073   0.2082680  -3.686            0.6048359
# 12      1            -0.4552073   0.2082680  -3.686            0.6048359
# 13      1            -0.4552073   0.2082680  -3.686            0.6048359
# 14      1            -0.4552073   0.2082680  -3.686            0.6048359
# 15      1            -0.4552073   0.2082680  -3.686            0.6048359
# 16      1            -0.4552073   0.2082680  -3.686            0.6048359
# 17      1            -0.4552073   0.2082680  -3.686            0.6048359
# 18      1            -0.4552073   0.2082680  -3.686            0.6048359
# 19      1            -0.4552073   0.2082680  -3.686            0.6048359
# 20      2             0.1762110   0.5538878  -5.855           -0.4843304
# 21      2             0.1762110   0.5538878  -5.855           -0.4843304
# 22      2             0.1762110   0.5538878  -5.855           -0.4843304
# 23      2             0.1762110   0.5538878  -5.855           -0.4843304
# 24      2             0.1762110   0.5538878  -5.855           -0.4843304
# 25      2             0.1762110   0.5538878  -5.855           -0.4843304
# 26      2             0.1762110   0.5538878  -5.855           -0.4843304
# 27      2             0.1762110   0.5538878  -5.855           -0.4843304
# 28      2             0.1762110   0.5538878  -5.855           -0.4843304
# 29      2             0.1762110   0.5538878  -5.855           -0.4843304
# 30      2             0.1762110   0.5538878  -5.855           -0.4843304
# ⋮       ⋮            ⋮            ⋮          ⋮                ⋮
# 1129471 13           -0.3129272    0.3382260 -6.597           -0.28756523
# 1129472 13           -0.3129272    0.3382260 -6.597           -0.28756523
# 1129473 13           -0.3129272    0.3382260 -6.597           -0.28756523
# 1129474 13           -0.3129272    0.3382260 -6.597           -0.28756523
# 1129475 13           -0.3129272    0.3382260 -6.597           -0.28756523
# 1129476 13           -0.3129272    0.3382260 -6.597           -0.28756523
# 1129477 13           -0.3129272    0.3382260 -6.597           -0.28756523
# 1129478 13           -0.3129272    0.3382260 -6.597           -0.28756523
# 1129479 13           -0.3129272    0.3382260 -6.597           -0.28756523
# 1129480 14            1.1027844   -0.2069195 -6.477            0.01181937
# 1129481 14            1.1027844   -0.2069195 -6.477            0.01181937
# 1129482 14            1.1027844   -0.2069195 -6.477            0.01181937
# 1129483 14            1.1027844   -0.2069195 -6.477            0.01181937
# 1129484 14            1.1027844   -0.2069195 -6.477            0.01181937
# 1129485 14            1.1027844   -0.2069195 -6.477            0.01181937
# 1129486 14            1.1027844   -0.2069195 -6.477            0.01181937
# 1129487 14            1.1027844   -0.2069195 -6.477            0.01181937
# 1129488 14            1.1027844   -0.2069195 -6.477            0.01181937
# 1129489 14            1.1027844   -0.2069195 -6.477            0.01181937
# 1129490 14            1.1027844   -0.2069195 -6.477            0.01181937
# 1129491 14            1.1027844   -0.2069195 -6.477            0.01181937
# 1129492 14            1.1027844   -0.2069195 -6.477            0.01181937
# 1129493 14            1.1027844   -0.2069195 -6.477            0.01181937
# 1129494 14            1.1027844   -0.2069195 -6.477            0.01181937
# 1129495 14            1.1027844   -0.2069195 -6.477            0.01181937
# 1129496 14            1.1027844   -0.2069195 -6.477            0.01181937
# 1129497 14            1.1027844   -0.2069195 -6.477            0.01181937
# 1129498 14            1.1027844   -0.2069195 -6.477            0.01181937
# 1129499 14            1.1027844   -0.2069195 -6.477            0.01181937
# 1129500 14            1.1027844   -0.2069195 -6.477            0.01181937
#         acousticness instrumentalness liveness   valence     tempo_overall
# 1        1.089605    -0.3659282        2.3954873 -0.6616794   0.66801566
# 2        1.089605    -0.3659282        2.3954873 -0.6616794   0.66801566
# 3        1.089605    -0.3659282        2.3954873 -0.6616794   0.66801566
# 4        1.089605    -0.3659282        2.3954873 -0.6616794   0.66801566
# 5        1.089605    -0.3659282        2.3954873 -0.6616794   0.66801566
# 6        1.089605    -0.3659282        2.3954873 -0.6616794   0.66801566
# 7        1.089605    -0.3659282        2.3954873 -0.6616794   0.66801566
# 8        1.089605    -0.3659282        2.3954873 -0.6616794   0.66801566
# 9        1.089605    -0.3659282        2.3954873 -0.6616794   0.66801566
# 10       1.089605    -0.3659282        2.3954873 -0.6616794   0.66801566
# 11       1.089605    -0.3659282        2.3954873 -0.6616794   0.66801566
# 12       1.089605    -0.3659282        2.3954873 -0.6616794   0.66801566
# 13       1.089605    -0.3659282        2.3954873 -0.6616794   0.66801566
# 14       1.089605    -0.3659282        2.3954873 -0.6616794   0.66801566
# 15       1.089605    -0.3659282        2.3954873 -0.6616794   0.66801566
# 16       1.089605    -0.3659282        2.3954873 -0.6616794   0.66801566
# 17       1.089605    -0.3659282        2.3954873 -0.6616794   0.66801566
# 18       1.089605    -0.3659282        2.3954873 -0.6616794   0.66801566
# 19       1.089605    -0.3659282        2.3954873 -0.6616794   0.66801566
# 20      -0.756834    -0.3700835       -0.7373967 -0.6016019  -0.01529824
# 21      -0.756834    -0.3700835       -0.7373967 -0.6016019  -0.01529824
# 22      -0.756834    -0.3700835       -0.7373967 -0.6016019  -0.01529824
# 23      -0.756834    -0.3700835       -0.7373967 -0.6016019  -0.01529824
# 24      -0.756834    -0.3700835       -0.7373967 -0.6016019  -0.01529824
# 25      -0.756834    -0.3700835       -0.7373967 -0.6016019  -0.01529824
# 26      -0.756834    -0.3700835       -0.7373967 -0.6016019  -0.01529824
# 27      -0.756834    -0.3700835       -0.7373967 -0.6016019  -0.01529824
# 28      -0.756834    -0.3700835       -0.7373967 -0.6016019  -0.01529824
# 29      -0.756834    -0.3700835       -0.7373967 -0.6016019  -0.01529824
# 30      -0.756834    -0.3700835       -0.7373967 -0.6016019  -0.01529824
# ⋮       ⋮            ⋮                ⋮          ⋮           ⋮
# 1129471 1.4222473    -0.3879681        1.4905999 -0.08400676 -0.5051205
# 1129472 1.4222473    -0.3879681        1.4905999 -0.08400676 -0.5051205
# 1129473 1.4222473    -0.3879681        1.4905999 -0.08400676 -0.5051205
# 1129474 1.4222473    -0.3879681        1.4905999 -0.08400676 -0.5051205
# 1129475 1.4222473    -0.3879681        1.4905999 -0.08400676 -0.5051205
# 1129476 1.4222473    -0.3879681        1.4905999 -0.08400676 -0.5051205
# 1129477 1.4222473    -0.3879681        1.4905999 -0.08400676 -0.5051205
# 1129478 1.4222473    -0.3879681        1.4905999 -0.08400676 -0.5051205
# 1129479 1.4222473    -0.3879681        1.4905999 -0.08400676 -0.5051205
# 1129480 0.3128629     3.1974158       -0.9449623  1.00709380 -0.5060791
# 1129481 0.3128629     3.1974158       -0.9449623  1.00709380 -0.5060791
# 1129482 0.3128629     3.1974158       -0.9449623  1.00709380 -0.5060791
# 1129483 0.3128629     3.1974158       -0.9449623  1.00709380 -0.5060791
# 1129484 0.3128629     3.1974158       -0.9449623  1.00709380 -0.5060791
# 1129485 0.3128629     3.1974158       -0.9449623  1.00709380 -0.5060791
# 1129486 0.3128629     3.1974158       -0.9449623  1.00709380 -0.5060791
# 1129487 0.3128629     3.1974158       -0.9449623  1.00709380 -0.5060791
# 1129488 0.3128629     3.1974158       -0.9449623  1.00709380 -0.5060791
# 1129489 0.3128629     3.1974158       -0.9449623  1.00709380 -0.5060791
# 1129490 0.3128629     3.1974158       -0.9449623  1.00709380 -0.5060791
# 1129491 0.3128629     3.1974158       -0.9449623  1.00709380 -0.5060791
# 1129492 0.3128629     3.1974158       -0.9449623  1.00709380 -0.5060791
# 1129493 0.3128629     3.1974158       -0.9449623  1.00709380 -0.5060791
# 1129494 0.3128629     3.1974158       -0.9449623  1.00709380 -0.5060791
# 1129495 0.3128629     3.1974158       -0.9449623  1.00709380 -0.5060791
# 1129496 0.3128629     3.1974158       -0.9449623  1.00709380 -0.5060791
# 1129497 0.3128629     3.1974158       -0.9449623  1.00709380 -0.5060791
# 1129498 0.3128629     3.1974158       -0.9449623  1.00709380 -0.5060791
# 1129499 0.3128629     3.1974158       -0.9449623  1.00709380 -0.5060791
# 1129500 0.3128629     3.1974158       -0.9449623  1.00709380 -0.5060791
#         loudness_continuouos tempo_continuous tempo_confidence mode_confidence
# 1       -0.8438937            0.615261000     0.328            0.816
# 2       -0.8438937            0.615261000     0.328            0.816
# 3       -0.8438937            0.615261000     0.328            0.816
# 4        0.6286434            0.603574700     0.429            0.499
# 5        0.6286434            0.603574700     0.429            0.499
# 6        0.6286434            0.603574700     0.429            0.499
# 7        0.8522504            0.599715650     0.329            0.577
# 8        0.8522504            0.599715650     0.329            0.577
# 9        0.7926218            0.644240200     0.232            0.684
# 10       0.7926218            0.644240200     0.232            0.684
# 11       0.7968063            0.589121500     0.312            0.460
# 12       0.7968063            0.589121500     0.312            0.460
# 13       0.7968063            0.589121500     0.312            0.460
# 14       0.6232820            0.609618070     0.293            0.819
# 15       0.6232820            0.609618070     0.293            0.819
# 16       0.6232820            0.609618070     0.293            0.819
# 17       0.9067791            0.583733440     0.215            0.636
# 18       0.9067791            0.583733440     0.215            0.636
# 19       0.9067791            0.583733440     0.215            0.636
# 20      -2.9340305           -0.162808150     0.133            0.000
# 21      -2.9340305           -0.162808150     0.133            0.000
# 22      -1.0127105            0.012850835     0.254            0.381
# 23      -1.0127105            0.012850835     0.254            0.381
# 24       0.3328545            0.014853165     0.290            0.550
# 25       0.6049750            0.009465076     0.325            0.481
# 26       0.6049750            0.009465076     0.325            0.481
# 27       0.3475001            0.012049902     0.258            0.611
# 28       0.3475001            0.012049902     0.258            0.611
# 29       0.6589807            0.008372896     0.326            0.447
# 30       0.6589807            0.008372896     0.326            0.447
# ⋮       ⋮                    ⋮                ⋮                ⋮
# 1129471  0.35123740          -0.3470523       0.604            0.369
# 1129472  0.35123740          -0.3470523       0.604            0.369
# 1129473  0.46796206          -0.3426994       0.511            0.426
# 1129474  0.18416493          -0.3534510       0.689            0.563
# 1129475  0.18416493          -0.3534510       0.689            0.563
# 1129476 -0.19149125          -0.3587180       0.511            0.545
# 1129477 -3.05987700          -0.3663791       0.686            0.198
# 1129478 -3.05987700          -0.3663791       0.686            0.198
# 1129479 -3.05987700          -0.3663791       0.686            0.198
# 1129480 -0.93889904          -0.3508393       0.625            0.000
# 1129481 -0.93889904          -0.3508393       0.625            0.000
# 1129482  0.04380761          -0.3507958       0.793            0.528
# 1129483  0.12641910          -0.3523628       0.783            0.296
# 1129484  0.12641910          -0.3523628       0.783            0.296
# 1129485  0.23492372          -0.3493158       0.757            0.400
# 1129486  0.36397848          -0.3532769       0.751            0.141
# 1129487  0.36397848          -0.3532769       0.751            0.141
# 1129488  0.37076000          -0.3556710       0.750            0.455
# 1129489  0.36027944          -0.3522758       0.690            0.116
# 1129490  0.36027944          -0.3522758       0.690            0.116
# 1129491  0.29945108          -0.3424382       0.774            0.000
# 1129492  0.44556242          -0.3530593       0.697            0.477
# 1129493  0.44556242          -0.3530593       0.697            0.477
# 1129494  0.44556242          -0.3530593       0.697            0.477
# 1129495  0.43323237          -0.3562804       0.758            0.363
# 1129496  0.54379200          -0.3584569       0.587            0.377
# 1129497  0.54379200          -0.3584569       0.587            0.377
# 1129498  0.22464865          -0.3521452       0.704            0.348
# 1129499 -4.33603900          -0.3579780       0.579            0.000
# 1129500 -4.33603900          -0.3579780       0.579            0.000
#         time_signature_confidence loudness   loudness_continuous
# 1       1.000                      1.3016131 -15.363
# 2       1.000                      1.3016131 -15.363
# 3       1.000                      1.3016131 -15.363
# 4       1.000                      1.3016131  -4.102
# 5       1.000                      1.3016131  -4.102
# 6       1.000                      1.3016131  -4.102
# 7       1.000                      1.3016131  -2.392
# 8       1.000                      1.3016131  -2.392
# 9       1.000                      1.3016131  -2.848
# 10      1.000                      1.3016131  -2.848
# 11      1.000                      1.3016131  -2.816
# 12      1.000                      1.3016131  -2.816
# 13      1.000                      1.3016131  -2.816
# 14      0.974                      1.3016131  -4.143
# 15      0.974                      1.3016131  -4.143
# 16      0.974                      1.3016131  -4.143
# 17      1.000                      1.3016131  -1.975
# 18      1.000                      1.3016131  -1.975
# 19      1.000                      1.3016131  -1.975
# 20      0.714                     -0.3593461 -31.347
# 21      0.714                     -0.3593461 -31.347
# 22      1.000                     -0.3593461 -16.654
# 23      1.000                     -0.3593461 -16.654
# 24      1.000                     -0.3593461  -6.364
# 25      1.000                     -0.3593461  -4.283
# 26      1.000                     -0.3593461  -4.283
# 27      1.000                     -0.3593461  -6.252
# 28      1.000                     -0.3593461  -6.252
# 29      1.000                     -0.3593461  -3.870
# 30      1.000                     -0.3593461  -3.870
# ⋮       ⋮                         ⋮          ⋮
# 1129471 1                         -1.0406250  -5.876
# 1129472 1                         -1.0406250  -5.876
# 1129473 1                         -1.0406250  -5.308
# 1129474 1                         -1.0406250  -6.689
# 1129475 1                         -1.0406250  -6.689
# 1129476 1                         -1.0406250  -8.517
# 1129477 1                         -1.0406250 -22.475
# 1129478 1                         -1.0406250 -22.475
# 1129479 1                         -1.0406250 -22.475
# 1129480 1                         -0.7656715 -12.154
# 1129481 1                         -0.7656715 -12.154
# 1129482 1                         -0.7656715  -7.372
# 1129483 1                         -0.7656715  -6.970
# 1129484 1                         -0.7656715  -6.970
# 1129485 1                         -0.7656715  -6.442
# 1129486 1                         -0.7656715  -5.814
# 1129487 1                         -0.7656715  -5.814
# 1129488 1                         -0.7656715  -5.781
# 1129489 1                         -0.7656715  -5.832
# 1129490 1                         -0.7656715  -5.832
# 1129491 1                         -0.7656715  -6.128
# 1129492 1                         -0.7656715  -5.417
# 1129493 1                         -0.7656715  -5.417
# 1129494 1                         -0.7656715  -5.417
# 1129495 1                         -0.7656715  -5.477
# 1129496 1                         -0.7656715  -4.939
# 1129497 1                         -0.7656715  -4.939
# 1129498 1                         -0.7656715  -6.492
# 1129499 1                         -0.7656715 -28.685
# 1129500 1                         -0.7656715 -28.685
#         track_id               album_id
# 1       6NfbN4Cl1lzkPrL0X722TA 007bD7YMU5GUUNzNWKGfoV
# 2       6NfbN4Cl1lzkPrL0X722TA 007bD7YMU5GUUNzNWKGfoV
# 3       6NfbN4Cl1lzkPrL0X722TA 007bD7YMU5GUUNzNWKGfoV
# 4       6NfbN4Cl1lzkPrL0X722TA 007bD7YMU5GUUNzNWKGfoV
# 5       6NfbN4Cl1lzkPrL0X722TA 007bD7YMU5GUUNzNWKGfoV
# 6       6NfbN4Cl1lzkPrL0X722TA 007bD7YMU5GUUNzNWKGfoV
# 7       6NfbN4Cl1lzkPrL0X722TA 007bD7YMU5GUUNzNWKGfoV
# 8       6NfbN4Cl1lzkPrL0X722TA 007bD7YMU5GUUNzNWKGfoV
# 9       6NfbN4Cl1lzkPrL0X722TA 007bD7YMU5GUUNzNWKGfoV
# 10      6NfbN4Cl1lzkPrL0X722TA 007bD7YMU5GUUNzNWKGfoV
# 11      6NfbN4Cl1lzkPrL0X722TA 007bD7YMU5GUUNzNWKGfoV
# 12      6NfbN4Cl1lzkPrL0X722TA 007bD7YMU5GUUNzNWKGfoV
# 13      6NfbN4Cl1lzkPrL0X722TA 007bD7YMU5GUUNzNWKGfoV
# 14      6NfbN4Cl1lzkPrL0X722TA 007bD7YMU5GUUNzNWKGfoV
# 15      6NfbN4Cl1lzkPrL0X722TA 007bD7YMU5GUUNzNWKGfoV
# 16      6NfbN4Cl1lzkPrL0X722TA 007bD7YMU5GUUNzNWKGfoV
# 17      6NfbN4Cl1lzkPrL0X722TA 007bD7YMU5GUUNzNWKGfoV
# 18      6NfbN4Cl1lzkPrL0X722TA 007bD7YMU5GUUNzNWKGfoV
# 19      6NfbN4Cl1lzkPrL0X722TA 007bD7YMU5GUUNzNWKGfoV
# 20      6NfbN4Cl1lzkPrL0X722TA 007bD7YMU5GUUNzNWKGfoV
# 21      6NfbN4Cl1lzkPrL0X722TA 007bD7YMU5GUUNzNWKGfoV
# 22      6NfbN4Cl1lzkPrL0X722TA 007bD7YMU5GUUNzNWKGfoV
# 23      6NfbN4Cl1lzkPrL0X722TA 007bD7YMU5GUUNzNWKGfoV
# 24      6NfbN4Cl1lzkPrL0X722TA 007bD7YMU5GUUNzNWKGfoV
# 25      6NfbN4Cl1lzkPrL0X722TA 007bD7YMU5GUUNzNWKGfoV
# 26      6NfbN4Cl1lzkPrL0X722TA 007bD7YMU5GUUNzNWKGfoV
# 27      6NfbN4Cl1lzkPrL0X722TA 007bD7YMU5GUUNzNWKGfoV
# 28      6NfbN4Cl1lzkPrL0X722TA 007bD7YMU5GUUNzNWKGfoV
# 29      6NfbN4Cl1lzkPrL0X722TA 007bD7YMU5GUUNzNWKGfoV
# 30      6NfbN4Cl1lzkPrL0X722TA 007bD7YMU5GUUNzNWKGfoV
# ⋮       ⋮                      ⋮
# 1129471 36oqHWt6Awhf4CXdu9axHf 7zYRc6LJv4eYF6fiQA5pF1
# 1129472 36oqHWt6Awhf4CXdu9axHf 7zYRc6LJv4eYF6fiQA5pF1
# 1129473 36oqHWt6Awhf4CXdu9axHf 7zYRc6LJv4eYF6fiQA5pF1
# 1129474 36oqHWt6Awhf4CXdu9axHf 7zYRc6LJv4eYF6fiQA5pF1
# 1129475 36oqHWt6Awhf4CXdu9axHf 7zYRc6LJv4eYF6fiQA5pF1
# 1129476 36oqHWt6Awhf4CXdu9axHf 7zYRc6LJv4eYF6fiQA5pF1
# 1129477 36oqHWt6Awhf4CXdu9axHf 7zYRc6LJv4eYF6fiQA5pF1
# 1129478 36oqHWt6Awhf4CXdu9axHf 7zYRc6LJv4eYF6fiQA5pF1
# 1129479 36oqHWt6Awhf4CXdu9axHf 7zYRc6LJv4eYF6fiQA5pF1
# 1129480 36oqHWt6Awhf4CXdu9axHf 7zYRc6LJv4eYF6fiQA5pF1
# 1129481 36oqHWt6Awhf4CXdu9axHf 7zYRc6LJv4eYF6fiQA5pF1
# 1129482 36oqHWt6Awhf4CXdu9axHf 7zYRc6LJv4eYF6fiQA5pF1
# 1129483 36oqHWt6Awhf4CXdu9axHf 7zYRc6LJv4eYF6fiQA5pF1
# 1129484 36oqHWt6Awhf4CXdu9axHf 7zYRc6LJv4eYF6fiQA5pF1
# 1129485 36oqHWt6Awhf4CXdu9axHf 7zYRc6LJv4eYF6fiQA5pF1
# 1129486 36oqHWt6Awhf4CXdu9axHf 7zYRc6LJv4eYF6fiQA5pF1
# 1129487 36oqHWt6Awhf4CXdu9axHf 7zYRc6LJv4eYF6fiQA5pF1
# 1129488 36oqHWt6Awhf4CXdu9axHf 7zYRc6LJv4eYF6fiQA5pF1
# 1129489 36oqHWt6Awhf4CXdu9axHf 7zYRc6LJv4eYF6fiQA5pF1
# 1129490 36oqHWt6Awhf4CXdu9axHf 7zYRc6LJv4eYF6fiQA5pF1
# 1129491 36oqHWt6Awhf4CXdu9axHf 7zYRc6LJv4eYF6fiQA5pF1
# 1129492 36oqHWt6Awhf4CXdu9axHf 7zYRc6LJv4eYF6fiQA5pF1
# 1129493 36oqHWt6Awhf4CXdu9axHf 7zYRc6LJv4eYF6fiQA5pF1
# 1129494 36oqHWt6Awhf4CXdu9axHf 7zYRc6LJv4eYF6fiQA5pF1
# 1129495 36oqHWt6Awhf4CXdu9axHf 7zYRc6LJv4eYF6fiQA5pF1
# 1129496 36oqHWt6Awhf4CXdu9axHf 7zYRc6LJv4eYF6fiQA5pF1
# 1129497 36oqHWt6Awhf4CXdu9axHf 7zYRc6LJv4eYF6fiQA5pF1
# 1129498 36oqHWt6Awhf4CXdu9axHf 7zYRc6LJv4eYF6fiQA5pF1
# 1129499 36oqHWt6Awhf4CXdu9axHf 7zYRc6LJv4eYF6fiQA5pF1
# 1129500 36oqHWt6Awhf4CXdu9axHf 7zYRc6LJv4eYF6fiQA5pF1

# %%
dissim_gen()
